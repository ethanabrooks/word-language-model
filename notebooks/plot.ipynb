# %%
import numpy as np
mapping = np.load('/home/jovyan/data/debug.npz')['mapping']
for i, row in enumerate(mapping.T):
    print(i, np.arange(mapping.shape[0])[row])
# Out:
# 0 [5 6 7]
# 1 [5 7]
# 2 [3 4]
# 3 [2 6]
# 4 []
# 5 [0]
# 6 [1 2 4]
# 7 [0 1 2 6]
# 8 [5]
# 9 []

# %%
arrays = np.load('checkpoint_9.npz')
for d, t in zip(arrays['data'], arrays['targets']):
    print(d, t)
# Out:
# 0 10
# 9 10
# 6 10
# 9 10
# 9 10
# 0 6
# 4 10
# 7 10
# 3 6
# 1 7
# 6 1
# 3 6
# 3 6
# 3 6
# 3 6
# 1 7
# 7 1
# 9 10
# 7 1
# 1 7
# 7 1
# 4 10
# 0 7
# 2 4
# 3 2
# 5 10
# 4 10
# 2 4
# 6 2
# 0 6
# 8 5
# 5 10
# 7 10
# 5 10
# 0 5

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
output = arrays['output']
n, d = output.shape
targets = arrays['targets']
im = ax.imshow(output)
plt.plot(targets, np.arange(len(targets)), '.')
# Out:
# <img src="data:image/png;base64,..." width="640">
